# %%
# %matplotlib inline

from __future__ import print_function
from sklearn import preprocessing
from time import time
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC
from sklearn.kernel_ridge import KernelRidge
import numpy as np
import sklearn.decomposition
import sklearn.metrics
from sklearn import gaussian_process
from sklearn import cross_validation
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
np.random.seed(1234)

# %%
#load 2015 and 2016 data into train and test data set 
horseData2015 = np.array(pd.read_excel('HorseCTrain.xlsx').values)
horseData2015 = np.vstack({tuple(row) for row in horseData2015})

horseData2016 = np.array(pd.read_excel('HorseCTest.xlsx').values)
horseData2016 = np.vstack({tuple(row) for row in horseData2016})

x_train = horseData2015[:, :-1];
y_train = horseData2015[:, -1:horseData2015[0].size];

x_test = horseData2016[:, :-1];
y_test = horseData2016[:, -1:horseData2016[0].size];

#smoooth y for both training and testing data
y_train = y_train.reshape(len(y_train),).astype(int) + (np.random.random_sample((len(y_train),))-1) + np.random.random_sample((len(y_train),))
y_test = y_test.reshape(len(y_test),).astype(int) + (np.random.random_sample((len(y_test),))-1) + np.random.random_sample((len(y_test),))

#smooth x_train for grid_search
X_train_smooth = preprocessing.scale(x_train)

# %%
param_grid = {"theta0": [0.005, 0.01, 0.015, 0.02, 0.025, 0.03, 0.035, 0.04, 0.045, 0.05, 0.055, 0.06, 0.065, 0.07],
              "nugget": [0.005, 0.01, 0.015, 0.02, 0.025, 0.03]}

reg_types = ['constant', 'linear']
corr_types = ['linear', 'absolute_exponential', 'cubic', 'squared_exponential']

num_top = 5
top_params = np.zeros((num_top,2))

# %%
def report(results, top_params):
    for i in range(1, num_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                 results['mean_test_score'][candidate],
                 results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")
            top_params[i-1][0] = results["params"][candidate]['nugget']
            top_params[i-1][1] = results["params"][candidate]['theta0']

# %%
def predictAll(theta, nugget, trainX, trainY, testX, testY, testSet, title, _reg, _corr):
    if _corr == 'squared_exponential' or _corr == 'generalized_exponential':
        rbf_thetaUU = [ 12, 5, 5, 7, 46.1, 126, 544.2, 45, 101.25, 8, 9, 8, 984517, 1, 0.5263, 0.5, 2]
        rbf_thetaLL = [ 5, 1, 1, 1, 0.1, 113, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001, 2, 6456, 0.0001, 0.0001, 0.0001, 1]
        rbf_theta0 = [ 8.4196, 2.5759, 1.5982, 2.3259, 6.1810, 120.2545, 169.2713, 36.9830, 13.9196, 3.0348, 3.0268, 3.9196, 102582.2589, 0.4433, 0.1843, 0.1086, 1.3750]
        rbf_thetaU = np.add((np.subtract(rbf_thetaUU, rbf_theta0)), rbf_theta0)
        rbf_thetaL = np.subtract(rbf_theta0, (np.subtract(rbf_theta0, rbf_thetaLL)))
        print(rbf_thetaU)
        print(rbf_thetaL)
        rbf_nugget = [3.285953444, 2.02995456, 0.642139668, 1.95182956, 65.89152618, 9.153997927, 21360.96237, 705.4621752, 145.8506856, 4.786432338, 6.472496811, 1.886399872, 14672819859, 0.045545572, 0.017114311, 0.008621105, 0.234375]
        
        gp = gaussian_process.GaussianProcess(regr=_reg, corr=_corr, theta0=rbf_theta0, thetaL = rbf_thetaL, thetaU = rbf_thetaU)
    else:
        gp = gaussian_process.GaussianProcess(regr=_reg, corr=_corr, theta0=theta, nugget =nugget)
    gp.fit(trainX, trainY)
    
    predictedY, MSE = gp.predict(testX, eval_MSE = True)
    sigma = np.sqrt(MSE)
    
    results = {}
    results['predictedY'] = predictedY
    results['sigma'] = sigma

    trainScore = gp.score(trainX, trainY)
    testScore = sklearn.metrics.r2_score(testY, predictedY)
    print ("Train score R2:", trainScore)
    print ("Test score R2:", testScore)
    
    return trainScore, testScore, results

# %%
def calculateError(predict, actual) :
    total =0.0
    for i in range(len(predict)):
        total += predict[i] - actual[i]
    return total/len(predict)

# %%
def runGP (_reg, _corr):
    clf = gaussian_process.GaussianProcess(regr=_reg, corr=_corr)
    print(clf.get_params().keys())
    
    grid_search = GridSearchCV(clf, param_grid=param_grid)
    start = time()
    grid_search.fit(X_train_smooth, y_train)
    print("BEST PARAMS: ", grid_search.best_params_)
    report(grid_search.cv_results_, top_params)
    print("GridSearchCV took %.2f seconds for %d candidate parameter settings."
          % (time() - start, len(grid_search.cv_results_['params'])))

    highestTest = 0;
    highestTest_Train = 0;
    highestTest_Error = 0;
    highestTest_theta = 0;
    highestTest_nugget = 0;
    
    for i in range(num_top):
        trainScore, testScore, results = predictAll(top_params[i][1], top_params[i][0], x_train, y_train, 
                                      x_test, y_test, x_test, 'Highest Speed Figure', _reg, _corr)
        err = calculateError(results['predictedY'],y_test)
        
        if testScore > highestTest:
            highestTest = testScore
            highestTest_Train = trainScore
            highestTest_Error = err
            highestTest_theta = top_params[i][1]
            highestTest_nugget = top_params[i][0]
          
    print()
    print("Highest Test Score: ", highestTest)
    print("Accompanying training Score: ", highestTest_Train)
    print("Accompanying error: ", highestTest_Error)
    print("Accompanying theta & nugget: ", highestTest_theta, " ", highestTest_nugget)
    print()

# %%
for j, reg in enumerate(reg_types):
    for k, corr in enumerate(corr_types):
        print ("Regression Model: ", reg, " Correlation Model: ", corr)
        runGP(reg,corr)
# Out:
# Regression Model:  constant  Correlation Model:  linear
# dict_keys(['nugget', 'verbose', 'thetaL', 'storage_mode', 'random_start', 'optimizer', 'beta0', 'normalize', 'regr', 'corr', 'theta0', 'random_state', 'thetaU'])
# BEST PARAMS:  {'theta0': 0.005, 'nugget': 0.02}
# Model with rank: 1
# Mean validation score: 0.776 (std: 0.037)
# Parameters: {'theta0': 0.005, 'nugget': 0.02}
#
# Model with rank: 2
# Mean validation score: 0.776 (std: 0.036)
# Parameters: {'theta0': 0.005, 'nugget': 0.015}
#
# Model with rank: 3
# Mean validation score: 0.775 (std: 0.038)
# Parameters: {'theta0': 0.005, 'nugget': 0.025}
#
# Model with rank: 4
# Mean validation score: 0.773 (std: 0.039)
# Parameters: {'theta0': 0.005, 'nugget': 0.03}
#
# Model with rank: 5
# Mean validation score: 0.773 (std: 0.032)
# Parameters: {'theta0': 0.01, 'nugget': 0.03}
#
# GridSearchCV took 2.09 seconds for 84 candidate parameter settings.
# Train score R2: 0.95286062821
# Test score R2: 0.80808810982
# Train score R2: 0.960691107179
# Test score R2: 0.818168460745
# Train score R2: 0.946143216418
# Test score R2: 0.799533717759
# Train score R2: 0.940173810104
# Test score R2: 0.792046181885
# Train score R2: 0.965284416089
# Test score R2: 0.827351265183
#
# Highest Test Score:  0.827351265183
# Accompanying training Score:  0.965284416089
# Accompanying error:  0.329800265966
# Accompanying theta & nugget:  0.01   0.03
#
# Regression Model:  constant  Correlation Model:  absolute_exponential
# dict_keys(['nugget', 'verbose', 'thetaL', 'storage_mode', 'random_start', 'optimizer', 'beta0', 'normalize', 'regr', 'corr', 'theta0', 'random_state', 'thetaU'])
# BEST PARAMS:  {'theta0': 0.005, 'nugget': 0.02}
# Model with rank: 1
# Mean validation score: 0.776 (std: 0.037)
# Parameters: {'theta0': 0.005, 'nugget': 0.02}
#
# Model with rank: 2
# Mean validation score: 0.776 (std: 0.036)
# Parameters: {'theta0': 0.005, 'nugget': 0.015}
#
# Model with rank: 3
# Mean validation score: 0.775 (std: 0.038)
# Parameters: {'theta0': 0.005, 'nugget': 0.025}
#
# Model with rank: 4
# Mean validation score: 0.774 (std: 0.033)
# Parameters: {'theta0': 0.01, 'nugget': 0.03}
#
# Model with rank: 5
# Mean validation score: 0.774 (std: 0.032)
# Parameters: {'theta0': 0.01, 'nugget': 0.025}
#
# GridSearchCV took 1.65 seconds for 84 candidate parameter settings.
# Train score R2: 0.952788943216
# Test score R2: 0.808081537671
# Train score R2: 0.960625304884
# Test score R2: 0.818158974032
# Train score R2: 0.94606645199
# Test score R2: 0.799532979605
# Train score R2: 0.965126475606
# Test score R2: 0.827314648272
# Train score R2: 0.969671715792
# Test score R2: 0.833138696062
#
# Highest Test Score:  0.833138696062
# Accompanying training Score:  0.969671715792
# Accompanying error:  0.375391135178
# Accompanying theta & nugget:  0.01   0.025
#
# Regression Model:  constant  Correlation Model:  cubic
# dict_keys(['nugget', 'verbose', 'thetaL', 'storage_mode', 'random_start', 'optimizer', 'beta0', 'normalize', 'regr', 'corr', 'theta0', 'random_state', 'thetaU'])
# BEST PARAMS:  {'theta0': 0.03, 'nugget': 0.005}
# Model with rank: 1
# Mean validation score: 0.663 (std: 0.018)
# Parameters: {'theta0': 0.03, 'nugget': 0.005}
#
# Model with rank: 2
# Mean validation score: 0.662 (std: 0.018)
# Parameters: {'theta0': 0.035, 'nugget': 0.005}
#
# Model with rank: 3
# Mean validation score: 0.655 (std: 0.020)
# Parameters: {'theta0': 0.04, 'nugget': 0.01}
#
# Model with rank: 4
# Mean validation score: 0.655 (std: 0.019)
# Parameters: {'theta0': 0.04, 'nugget': 0.005}
#
# Model with rank: 5
# Mean validation score: 0.654 (std: 0.018)
# Parameters: {'theta0': 0.035, 'nugget': 0.01}
#
# GridSearchCV took 2.44 seconds for 84 candidate parameter settings.
# Train score R2: 0.913481101976
# Test score R2: 0.660588195289
# Train score R2: 0.931459721583
# Test score R2: 0.699048079905
# Train score R2: 0.922048467071
# Test score R2: 0.670961351858
# Train score R2: 0.945013442488
# Test score R2: 0.72615370295
# Train score R2: 0.904740211264
# Test score R2: 0.635478147843
#
# Highest Test Score:  0.72615370295
# Accompanying training Score:  0.945013442488
# Accompanying error:  0.278114951924
# Accompanying theta & nugget:  0.04   0.005
#
# Regression Model:  constant  Correlation Model:  squared_exponential
# dict_keys(['nugget', 'verbose', 'thetaL', 'storage_mode', 'random_start', 'optimizer', 'beta0', 'normalize', 'regr', 'corr', 'theta0', 'random_state', 'thetaU'])
# BEST PARAMS:  {'theta0': 0.005, 'nugget': 0.015}
# Model with rank: 1
# Mean validation score: 0.602 (std: 0.033)
# Parameters: {'theta0': 0.005, 'nugget': 0.015}
#
# Model with rank: 2
# Mean validation score: 0.601 (std: 0.028)
# Parameters: {'theta0': 0.005, 'nugget': 0.02}
#
# Model with rank: 3
# Mean validation score: 0.601 (std: 0.039)
# Parameters: {'theta0': 0.005, 'nugget': 0.01}
#
# Model with rank: 4
# Mean validation score: 0.601 (std: 0.040)
# Parameters: {'theta0': 0.01, 'nugget': 0.03}
#
# Model with rank: 5
# Mean validation score: 0.600 (std: 0.024)
# Parameters: {'theta0': 0.005, 'nugget': 0.025}
#
# GridSearchCV took 1.65 seconds for 84 candidate parameter settings.
# [  1.20000000e+01   5.00000000e+00   5.00000000e+00   7.00000000e+00
#    4.61000000e+01   1.26000000e+02   5.44200000e+02   4.50000000e+01
#    1.01250000e+02   8.00000000e+00   9.00000000e+00   8.00000000e+00
#    9.84517000e+05   1.00000000e+00   5.26300000e-01   5.00000000e-01
#    2.00000000e+00]
# [  5.00000000e+00   1.00000000e+00   1.00000000e+00   1.00000000e+00
#    1.00000000e-01   1.13000000e+02   1.00000000e-04   1.00000000e-04
#    1.00000000e-04   1.00000000e-04   1.00000000e-04   2.00000000e+00
#    6.45600000e+03   1.00000000e-04   1.00000000e-04   1.00000000e-04
#    1.00000000e+00]
# Train score R2: 1.0
# Test score R2: 0.56543362367
# [  1.20000000e+01   5.00000000e+00   5.00000000e+00   7.00000000e+00
#    4.61000000e+01   1.26000000e+02   5.44200000e+02   4.50000000e+01
#    1.01250000e+02   8.00000000e+00   9.00000000e+00   8.00000000e+00
#    9.84517000e+05   1.00000000e+00   5.26300000e-01   5.00000000e-01
#    2.00000000e+00]
# [  5.00000000e+00   1.00000000e+00   1.00000000e+00   1.00000000e+00
#    1.00000000e-01   1.13000000e+02   1.00000000e-04   1.00000000e-04
#    1.00000000e-04   1.00000000e-04   1.00000000e-04   2.00000000e+00
#    6.45600000e+03   1.00000000e-04   1.00000000e-04   1.00000000e-04
#    1.00000000e+00]
# Train score R2: 1.0
# Test score R2: 0.56543362367
# [  1.20000000e+01   5.00000000e+00   5.00000000e+00   7.00000000e+00
#    4.61000000e+01   1.26000000e+02   5.44200000e+02   4.50000000e+01
#    1.01250000e+02   8.00000000e+00   9.00000000e+00   8.00000000e+00
#    9.84517000e+05   1.00000000e+00   5.26300000e-01   5.00000000e-01
#    2.00000000e+00]
# [  5.00000000e+00   1.00000000e+00   1.00000000e+00   1.00000000e+00
#    1.00000000e-01   1.13000000e+02   1.00000000e-04   1.00000000e-04
#    1.00000000e-04   1.00000000e-04   1.00000000e-04   2.00000000e+00
#    6.45600000e+03   1.00000000e-04   1.00000000e-04   1.00000000e-04
#    1.00000000e+00]
# Train score R2: 1.0
# Test score R2: 0.56543362367
# [  1.20000000e+01   5.00000000e+00   5.00000000e+00   7.00000000e+00
#    4.61000000e+01   1.26000000e+02   5.44200000e+02   4.50000000e+01
#    1.01250000e+02   8.00000000e+00   9.00000000e+00   8.00000000e+00
#    9.84517000e+05   1.00000000e+00   5.26300000e-01   5.00000000e-01
#    2.00000000e+00]
# [  5.00000000e+00   1.00000000e+00   1.00000000e+00   1.00000000e+00
#    1.00000000e-01   1.13000000e+02   1.00000000e-04   1.00000000e-04
#    1.00000000e-04   1.00000000e-04   1.00000000e-04   2.00000000e+00
#    6.45600000e+03   1.00000000e-04   1.00000000e-04   1.00000000e-04
#    1.00000000e+00]
# Train score R2: 1.0
# Test score R2: 0.56543362367
# [  1.20000000e+01   5.00000000e+00   5.00000000e+00   7.00000000e+00
#    4.61000000e+01   1.26000000e+02   5.44200000e+02   4.50000000e+01
#    1.01250000e+02   8.00000000e+00   9.00000000e+00   8.00000000e+00
#    9.84517000e+05   1.00000000e+00   5.26300000e-01   5.00000000e-01
#    2.00000000e+00]
# [  5.00000000e+00   1.00000000e+00   1.00000000e+00   1.00000000e+00
#    1.00000000e-01   1.13000000e+02   1.00000000e-04   1.00000000e-04
#    1.00000000e-04   1.00000000e-04   1.00000000e-04   2.00000000e+00
#    6.45600000e+03   1.00000000e-04   1.00000000e-04   1.00000000e-04
#    1.00000000e+00]
# Train score R2: 1.0
# Test score R2: 0.56543362367
#
# Highest Test Score:  0.56543362367
# Accompanying training Score:  1.0
# Accompanying error:  0.0782699331592
# Accompanying theta & nugget:  0.005   0.015
#
# Regression Model:  linear  Correlation Model:  linear
# dict_keys(['nugget', 'verbose', 'thetaL', 'storage_mode', 'random_start', 'optimizer', 'beta0', 'normalize', 'regr', 'corr', 'theta0', 'random_state', 'thetaU'])
# BEST PARAMS:  {'theta0': 0.005, 'nugget': 0.01}
# Model with rank: 1
# Mean validation score: 0.700 (std: 0.047)
# Parameters: {'theta0': 0.005, 'nugget': 0.01}
#
# Model with rank: 2
# Mean validation score: 0.699 (std: 0.050)
# Parameters: {'theta0': 0.005, 'nugget': 0.015}
#
# Model with rank: 3
# Mean validation score: 0.696 (std: 0.043)
# Parameters: {'theta0': 0.005, 'nugget': 0.005}
#
# Model with rank: 4
# Mean validation score: 0.695 (std: 0.053)
# Parameters: {'theta0': 0.005, 'nugget': 0.02}
#
# Model with rank: 5
# Mean validation score: 0.695 (std: 0.056)
# Parameters: {'theta0': 0.01, 'nugget': 0.02}
#
# GridSearchCV took 1.94 seconds for 84 candidate parameter settings.
# Train score R2: 0.971084318722
# Test score R2: 0.749159491379
# Train score R2: 0.962246356745
# Test score R2: 0.719048881742
# Train score R2: 0.983275810475
# Test score R2: 0.791043274579
# Train score R2: 0.955198165205
# Test score R2: 0.69421531689
# Train score R2: 0.975371895044
# Test score R2: 0.756897076476
#
# Highest Test Score:  0.791043274579
# Accompanying training Score:  0.983275810475
# Accompanying error:  0.635507535612
# Accompanying theta & nugget:  0.005   0.005
#
# Regression Model:  linear  Correlation Model:  absolute_exponential
# dict_keys(['nugget', 'verbose', 'thetaL', 'storage_mode', 'random_start', 'optimizer', 'beta0', 'normalize', 'regr', 'corr', 'theta0', 'random_state', 'thetaU'])
# BEST PARAMS:  {'theta0': 0.005, 'nugget': 0.01}
# Model with rank: 1
# Mean validation score: 0.700 (std: 0.047)
# Parameters: {'theta0': 0.005, 'nugget': 0.01}
#
# Model with rank: 2
# Mean validation score: 0.699 (std: 0.050)
# Parameters: {'theta0': 0.005, 'nugget': 0.015}
#
# Model with rank: 3
# Mean validation score: 0.696 (std: 0.043)
# Parameters: {'theta0': 0.005, 'nugget': 0.005}
#
# Model with rank: 4
# Mean validation score: 0.696 (std: 0.053)
# Parameters: {'theta0': 0.005, 'nugget': 0.02}
#
# Model with rank: 5
# Mean validation score: 0.695 (std: 0.056)
# Parameters: {'theta0': 0.01, 'nugget': 0.02}
#
# GridSearchCV took 1.78 seconds for 84 candidate parameter settings.
# Train score R2: 0.971036715103
# Test score R2: 0.749076151118
# Train score R2: 0.962197486461
# Test score R2: 0.718967114549
# Train score R2: 0.983237127398
# Test score R2: 0.790972776441
# Train score R2: 0.955150321239
# Test score R2: 0.694138478801
# Train score R2: 0.975256036633
# Test score R2: 0.756744663107
#
# Highest Test Score:  0.790972776441
# Accompanying training Score:  0.983237127398
# Accompanying error:  0.634988010569
# Accompanying theta & nugget:  0.005   0.005
#
# Regression Model:  linear  Correlation Model:  cubic
# dict_keys(['nugget', 'verbose', 'thetaL', 'storage_mode', 'random_start', 'optimizer', 'beta0', 'normalize', 'regr', 'corr', 'theta0', 'random_state', 'thetaU'])
# BEST PARAMS:  {'theta0': 0.04, 'nugget': 0.005}
# Model with rank: 1
# Mean validation score: 0.662 (std: 0.036)
# Parameters: {'theta0': 0.04, 'nugget': 0.005}
#
# Model with rank: 2
# Mean validation score: 0.660 (std: 0.029)
# Parameters: {'theta0': 0.045, 'nugget': 0.005}
#
# Model with rank: 3
# Mean validation score: 0.660 (std: 0.043)
# Parameters: {'theta0': 0.035, 'nugget': 0.005}
#
# Model with rank: 4
# Mean validation score: 0.658 (std: 0.024)
# Parameters: {'theta0': 0.05, 'nugget': 0.005}
#
# Model with rank: 5
# Mean validation score: 0.654 (std: 0.021)
# Parameters: {'theta0': 0.055, 'nugget': 0.005}
#
# GridSearchCV took 2.56 seconds for 84 candidate parameter settings.
# Train score R2: 0.947699550485
# Test score R2: 0.605483996614
# Train score R2: 0.958086942935
# Test score R2: 0.649706141645
# Train score R2: 0.934616843005
# Test score R2: 0.551432576906
# Train score R2: 0.966462868866
# Test score R2: 0.685278565586
# Train score R2: 0.973262993092
# Test score R2: 0.712768498408
#
# Highest Test Score:  0.712768498408
# Accompanying training Score:  0.973262993092
# Accompanying error:  0.520361101323
# Accompanying theta & nugget:  0.055   0.005
#
# Regression Model:  linear  Correlation Model:  squared_exponential
# dict_keys(['nugget', 'verbose', 'thetaL', 'storage_mode', 'random_start', 'optimizer', 'beta0', 'normalize', 'regr', 'corr', 'theta0', 'random_state', 'thetaU'])
# BEST PARAMS:  {'theta0': 0.02, 'nugget': 0.02}
# Model with rank: 1
# Mean validation score: 0.625 (std: 0.049)
# Parameters: {'theta0': 0.02, 'nugget': 0.02}
#
# Model with rank: 2
# Mean validation score: 0.625 (std: 0.047)
# Parameters: {'theta0': 0.02, 'nugget': 0.015}
#
# Model with rank: 3
# Mean validation score: 0.624 (std: 0.054)
# Parameters: {'theta0': 0.015, 'nugget': 0.015}
#
# Model with rank: 4
# Mean validation score: 0.623 (std: 0.042)
# Parameters: {'theta0': 0.025, 'nugget': 0.02}
#
# Model with rank: 5
# Mean validation score: 0.623 (std: 0.045)
# Parameters: {'theta0': 0.025, 'nugget': 0.025}
#
# GridSearchCV took 1.77 seconds for 84 candidate parameter settings.
# [  1.20000000e+01   5.00000000e+00   5.00000000e+00   7.00000000e+00
#    4.61000000e+01   1.26000000e+02   5.44200000e+02   4.50000000e+01
#    1.01250000e+02   8.00000000e+00   9.00000000e+00   8.00000000e+00
#    9.84517000e+05   1.00000000e+00   5.26300000e-01   5.00000000e-01
#    2.00000000e+00]
# [  5.00000000e+00   1.00000000e+00   1.00000000e+00   1.00000000e+00
#    1.00000000e-01   1.13000000e+02   1.00000000e-04   1.00000000e-04
#    1.00000000e-04   1.00000000e-04   1.00000000e-04   2.00000000e+00
#    6.45600000e+03   1.00000000e-04   1.00000000e-04   1.00000000e-04
#    1.00000000e+00]
# Train score R2: 1.0
# Test score R2: 0.104972626719
# [  1.20000000e+01   5.00000000e+00   5.00000000e+00   7.00000000e+00
#    4.61000000e+01   1.26000000e+02   5.44200000e+02   4.50000000e+01
#    1.01250000e+02   8.00000000e+00   9.00000000e+00   8.00000000e+00
#    9.84517000e+05   1.00000000e+00   5.26300000e-01   5.00000000e-01
#    2.00000000e+00]
# [  5.00000000e+00   1.00000000e+00   1.00000000e+00   1.00000000e+00
#    1.00000000e-01   1.13000000e+02   1.00000000e-04   1.00000000e-04
#    1.00000000e-04   1.00000000e-04   1.00000000e-04   2.00000000e+00
#    6.45600000e+03   1.00000000e-04   1.00000000e-04   1.00000000e-04
#    1.00000000e+00]
# Train score R2: 1.0
# Test score R2: 0.104972626719
# [  1.20000000e+01   5.00000000e+00   5.00000000e+00   7.00000000e+00
#    4.61000000e+01   1.26000000e+02   5.44200000e+02   4.50000000e+01
#    1.01250000e+02   8.00000000e+00   9.00000000e+00   8.00000000e+00
#    9.84517000e+05   1.00000000e+00   5.26300000e-01   5.00000000e-01
#    2.00000000e+00]
# [  5.00000000e+00   1.00000000e+00   1.00000000e+00   1.00000000e+00
#    1.00000000e-01   1.13000000e+02   1.00000000e-04   1.00000000e-04
#    1.00000000e-04   1.00000000e-04   1.00000000e-04   2.00000000e+00
#    6.45600000e+03   1.00000000e-04   1.00000000e-04   1.00000000e-04
#    1.00000000e+00]
# Train score R2: 1.0
# Test score R2: 0.104972626719
# [  1.20000000e+01   5.00000000e+00   5.00000000e+00   7.00000000e+00
#    4.61000000e+01   1.26000000e+02   5.44200000e+02   4.50000000e+01
#    1.01250000e+02   8.00000000e+00   9.00000000e+00   8.00000000e+00
#    9.84517000e+05   1.00000000e+00   5.26300000e-01   5.00000000e-01
#    2.00000000e+00]
# [  5.00000000e+00   1.00000000e+00   1.00000000e+00   1.00000000e+00
#    1.00000000e-01   1.13000000e+02   1.00000000e-04   1.00000000e-04
#    1.00000000e-04   1.00000000e-04   1.00000000e-04   2.00000000e+00
#    6.45600000e+03   1.00000000e-04   1.00000000e-04   1.00000000e-04
#    1.00000000e+00]
# Train score R2: 1.0
# Test score R2: 0.104972626719
# [  1.20000000e+01   5.00000000e+00   5.00000000e+00   7.00000000e+00
#    4.61000000e+01   1.26000000e+02   5.44200000e+02   4.50000000e+01
#    1.01250000e+02   8.00000000e+00   9.00000000e+00   8.00000000e+00
#    9.84517000e+05   1.00000000e+00   5.26300000e-01   5.00000000e-01
#    2.00000000e+00]
# [  5.00000000e+00   1.00000000e+00   1.00000000e+00   1.00000000e+00
#    1.00000000e-01   1.13000000e+02   1.00000000e-04   1.00000000e-04
#    1.00000000e-04   1.00000000e-04   1.00000000e-04   2.00000000e+00
#    6.45600000e+03   1.00000000e-04   1.00000000e-04   1.00000000e-04
#    1.00000000e+00]
# Train score R2: 1.0
# Test score R2: 0.104972626719
#
# Highest Test Score:  0.104972626719
# Accompanying training Score:  1.0
# Accompanying error:  0.472855150503
# Accompanying theta & nugget:  0.02   0.02

# %%
trainScore, testScore, results = predictAll(0, 0, x_train, y_train, 
                                      x_test, y_test, x_test, 'Highest Speed Figure', 'linear', 'squared_exponential')
print(trainScore)
print(testScore)
# Out:
# [  1.20000000e+01   5.00000000e+00   5.00000000e+00   7.00000000e+00
#    4.61000000e+01   1.26000000e+02   5.44200000e+02   4.50000000e+01
#    1.01250000e+02   8.00000000e+00   9.00000000e+00   8.00000000e+00
#    9.84517000e+05   1.00000000e+00   5.26300000e-01   5.00000000e-01
#    2.00000000e+00]
# [  5.00000000e+00   1.00000000e+00   1.00000000e+00   1.00000000e+00
#    1.00000000e-01   1.13000000e+02   1.00000000e-04   1.00000000e-04
#    1.00000000e-04   1.00000000e-04   1.00000000e-04   2.00000000e+00
#    6.45600000e+03   1.00000000e-04   1.00000000e-04   1.00000000e-04
#    1.00000000e+00]
# Train score R2: 1.0
# Test score R2: 0.104972626719
# 1.0
# 0.104972626719
